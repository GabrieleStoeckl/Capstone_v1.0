# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ##Load data and remove irrelevant variables

# %%
data = pd.read_csv("../02_data_preparation/yoghurt_w_dummy_data.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21251 entries, 0 to 21250
# Data columns (total 67 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 21251 non-null  int64
#  1   first_purchase             21251 non-null  bool
#  2   shelf_price                21251 non-null  float64
#  3   pct_disc                   21251 non-null  float64
#  4   pct_retail_disc            21251 non-null  float64
#  5   pct_coupon_disc            21251 non-null  float64
#  6   display_1                  21251 non-null  int64
#  7   display_2                  21251 non-null  int64
#  8   display_3                  21251 non-null  int64
#  9   display_4                  21251 non-null  int64
#  10  display_5                  21251 non-null  int64
#  11  display_6                  21251 non-null  int64
#  12  display_7                  21251 non-null  int64
# ...

# %%
data.drop(labels=["Unnamed: 0", "display_1", "display_5", "display_A", "campaign_6.0", "campaign_30.0", "description_TypeC"],
          axis = 1, inplace = True)

# %%
pd.set_option("display.max_columns", None)
data.describe(include = "all")
# Out:
#        first_purchase   shelf_price      pct_disc  pct_retail_disc  \
# count           21251  21251.000000  21251.000000     21251.000000
# unique              2           NaN           NaN              NaN
# top             False           NaN           NaN              NaN
# freq            14083           NaN           NaN              NaN
# mean              NaN      1.156933      0.158316         0.153330
# std               NaN      1.104681      0.145841         0.137543
# min               NaN      0.350000      0.000000        -0.000000
# 25%               NaN      0.400000      0.000000        -0.000000
# 50%               NaN      0.790000      0.166667         0.163180
# 75%               NaN      0.790000      0.240506         0.240506
# max               NaN      6.590000      0.909091         0.702341
#
#         pct_coupon_disc     display_2     display_3     display_4  \
# count      21251.000000  21251.000000  21251.000000  21251.000000
# ...

# %% [markdown]
# ## Build XGBoost model

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedShuffleSplit, StratifiedKFold
from sklearn.model_selection import learning_curve, validation_curve
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

import lightgbm as lgb

# %%
X = data.drop("first_purchase", axis = 1)
y = data["first_purchase"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8, stratify = y)

# %%
lgbm =  lgb.LGBMClassifier()
lgbm.fit(X_train, y_train)
# Out:
# LGBMClassifier()

# %%
cv = StratifiedShuffleSplit(n_splits = 5)

# %%
#crossval metrics for xgb base model
scores = ["f1", "precision", "recall", "accuracy"]

for score in scores:
    list_scores = cross_val_score(lgbm, X_train, y_train, cv=cv, scoring = score )
    print(list_scores.mean())
# Out:
# 0.49910504459258986
# 0.6949659853304456
# 0.40279232111692853
# 0.7351764705882354

# %%
y_pred = lgbm.predict(X_test)

# %%
#metrics for xgb base model - TEST
scores = [f1_score, precision_score, recall_score, accuracy_score]

for score in scores:
    print(score(y_test, y_pred))
# Out:
# 0.4874326750448834
# 0.6838790931989924
# 0.3786610878661088
# 0.7313573276876029

# %%
y_pred_train = lgbm.predict(X_train)
#metrics for model- TRAIN
scores = [f1_score, precision_score, recall_score, accuracy_score]

for score in scores:
    print(score(y_train, y_pred_train))
# Out:
# 0.5773286467486819
# 0.7798219584569733
# 0.45831880013951865
# 0.7736470588235295

# %%
lgbm.get_params()
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.1,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'num_leaves': 31,
#  'objective': None,
#  'random_state': None,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'silent': 'warn',
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0}

# %% [markdown]
# #Hyperparameter tuning

# %%
import scipy

# %%
rand_params = {'max_depth': scipy.stats.randint(5,30), "subsample": np.arange(0.6,1,0.1), "colsample_bytree": np.arange(0.6,1,0.1),
              "n_estimators": scipy.stats.randint(50, 250), "learning_rate": np.arange(0.05,0.3,0.05), "num_leaves": scipy.stats.randint(5,50),
              "boosting_type" : ["gbdt", "dart"]}

# %%
rand_search = RandomizedSearchCV(lgbm, rand_params, n_iter=30, scoring = "f1", cv = cv)

# %%
rand_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedShuffleSplit(n_splits=5, random_state=None, test_size=None,
#             train_size=None),
#                    estimator=LGBMClassifier(objective='binary'), n_iter=30,
#                    param_distributions={'boosting_type': ['gbdt', 'dart'],
#                                         'colsample_bytree': array([0.6, 0.7, 0.8, 0.9]),
#                                         'learning_rate': array([0.05, 0.1 , 0.15, 0.2 , 0.25]),
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000024D176B1A30>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000024D1408AD30>,
#                                         'num_leaves': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000024D176B1D60>,
#                                         'subsample': array([0.6, 0.7, 0.8, 0.9])},
#                    scoring='f1')

# %%
rand_search.best_score_
# Out:
# 0.6015655763996939

# %%
rand_search.best_params_
# Out:
# {'boosting_type': 'gbdt',
#  'colsample_bytree': 0.7,
#  'learning_rate': 0.2,
#  'max_depth': 26,
#  'n_estimators': 211,
#  'num_leaves': 49,
#  'subsample': 0.7}

# %%
rand_params_2 = {'max_depth': scipy.stats.randint(20,30), "subsample": np.arange(0.6,0.8,0.1), "colsample_bytree": np.arange(0.6,0.8,0.1),
              "n_estimators": scipy.stats.randint(175, 250), "learning_rate": np.arange(0.05,0.3,0.05), "num_leaves": scipy.stats.randint(25,40),
              "boosting_type" : ["gbdt", "dart"]}

# %%
rand_search = RandomizedSearchCV(lgbm, rand_params_2, n_iter=30, scoring = "f1", cv = cv)
rand_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedShuffleSplit(n_splits=5, random_state=None, test_size=None,
#             train_size=None),
#                    estimator=LGBMClassifier(objective='binary'), n_iter=30,
#                    param_distributions={'boosting_type': ['gbdt', 'dart'],
#                                         'colsample_bytree': array([0.6, 0.7, 0.8]),
#                                         'learning_rate': array([0.05, 0.1 , 0.15, 0.2 , 0.25]),
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000024D17628D90>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000024D16D0ECD0>,
#                                         'num_leaves': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000024D17628430>,
#                                         'subsample': array([0.6, 0.7, 0.8])},
#                    scoring='f1')

# %%
rand_search.best_score_
# Out:
# 0.6008051728345529

# %%
rand_search.best_params_
# Out:
# {'boosting_type': 'gbdt',
#  'colsample_bytree': 0.7999999999999999,
#  'learning_rate': 0.2,
#  'max_depth': 27,
#  'n_estimators': 249,
#  'num_leaves': 32,
#  'subsample': 0.7999999999999999}

# %% [markdown]
# #Validation

# %%
from plotting import plot_learning_curve, plot_validation_curve

# %%
learning_curve = plot_learning_curve(rand_search.best_estimator_, X_train, y_train, cv = cv,  
                          train_sizes = np.linspace(.1, 1, 10), scoring = "f1")

# %%
val_boosting_type = plot_validation_curve(rand_search.best_estimator_, X_train, y_train, cv = cv, 
                                      param_name ="boosting_type", param_range = ["gbdt", "dart"], scoring = "f1")

# %%
val_colsample_bytree = plot_validation_curve(rand_search.best_estimator_, X_train, y_train, cv=cv,
                                             param_name="colsample_bytree", param_range = np.arange(0.6,1,0.1), scoring = "f1")

# %%
val_learning_rate = plot_validation_curve(rand_search.best_estimator_, X_train, y_train, cv=cv,
                                              param_name = "learning_rate", param_range = np.arange(0.05,0.3,0.05), scoring="f1")

# %%
val_max_depth = plot_validation_curve(rand_search.best_estimator_, X_train, y_train, cv=cv,
                                              param_name = "max_depth", param_range = np.arange(5,30,7), scoring="f1")

# %%
val_n_estimators = plot_validation_curve(rand_search.best_estimator_, X_train, y_train, cv=cv,
                                              param_name = "n_estimators", param_range = np.arange(50,250,6), scoring="f1")

# %%
val_num_leaves = plot_validation_curve(rand_search.best_estimator_, X_train, y_train, cv=cv,
                                              param_name = "num_leaves", param_range = np.arange(5, 50, 11), scoring="f1")

# %%
val_subsample = plot_validation_curve(rand_search.best_estimator_, X_train, y_train, cv=cv,
                                              param_name = "subsample", param_range = np.arange(0.6,1,0.1), scoring="f1")

# %% [markdown]
# #Best model

# %%
fav_model_1 = lgb.LGBMClassifier(num_leaves = 30, max_depth = 12, subsample = 0.7, learning_rate = 0.15, boosting_type = "gbdt", colsample_bytree = 0.75, n_estimators = 225)
fav_model_2 = lgb.LGBMClassifier(num_leaves = 49, max_depth = 20, subsample = 0.7, learning_rate = 0.2, boosting_type = "gbdt", colsample_bytree = 0.75, n_estimators = 225)
fav_model_1.fit(X_train, y_train)
fav_model_2.fit(X_train, y_train)
# Out:
# LGBMClassifier(colsample_bytree=0.75, learning_rate=0.2, max_depth=20,
#                n_estimators=225, num_leaves=49, subsample=0.7)

# %%
#crossval metrics for fav1 model
scores = ["f1", "precision", "recall", "accuracy"]

for score in scores:
    list_scores = cross_val_score(fav_model_1, X_train, y_train, cv=cv, scoring = score )
    print(list_scores.mean())
# Out:
# 0.5729486984431045
# 0.6902379925875061
# 0.49214659685863876
# 0.7445882352941176

# %%
#crossval metrics for fav2 model
scores = ["f1", "precision", "recall", "accuracy"]

for score in scores:
    list_scores = cross_val_score(fav_model_2, X_train, y_train, cv=cv, scoring = score )
    print(list_scores.mean())
# Out:
# 0.5859561749907816
# 0.6853671103457716
# 0.5291448516579406
# 0.7665882352941176

# %%
y_pred_fav1 = fav_model_1.predict(X_test)
y_pred_fav2 = fav_model_2.predict(X_test)

# %%
#metrics for fav1 model - TEST
scores = [f1_score, precision_score, recall_score, accuracy_score]

for score in scores:
    print(score(y_test, y_pred_fav1))
# Out:
# 0.5607245780156443
# 0.6844221105527638
# 0.47489539748953974
# 0.7490002352387674

# %%
#metrics for fav2 model - TEST
scores = [f1_score, precision_score, recall_score, accuracy_score]

for score in scores:
    print(score(y_test, y_pred_fav2))
# Out:
# 0.6024285154719936
# 0.6872207327971404
# 0.5362622036262203
# 0.761232651140908

# %%
y_pred_fav1_train = fav_model_1.predict(X_train)
#metrics for fav1 model- TRAIN
scores = [f1_score, precision_score, recall_score, accuracy_score]

for score in scores:
    print(score(y_train, y_pred_fav1_train))
# Out:
# 0.6834120365718878
# 0.8061151931737378
# 0.5931287059644227
# 0.8146470588235294

# %%
y_pred_fav2_train = fav_model_2.predict(X_train)
#metrics for fav2 model- TRAIN
scores = [f1_score, precision_score, recall_score, accuracy_score]

for score in scores:
    print(score(y_train, y_pred_fav2_train))
# Out:
# 0.7344446598177942
# 0.8265706806282722
# 0.6607952563655389
# 0.8388235294117647

# %%
#model with rand_search best params

# %%
fav_model_rand = lgb.LGBMClassifier(num_leaves = 49, max_depth = 26, subsample = 0.7, learning_rate = 0.2, boosting_type = "gbdt", colsample_bytree = 0.7, n_estimators = 211)
fav_model_rand.fit(X_train, y_train)
# Out:
# LGBMClassifier(colsample_bytree=0.7, learning_rate=0.2, max_depth=26,
#                n_estimators=211, num_leaves=49, subsample=0.7)

# %%
#crossval metrics for fav-rand model
scores = ["f1", "precision", "recall", "accuracy"]

for score in scores:
    list_scores = cross_val_score(fav_model_rand, X_train, y_train, cv=cv, scoring = score )
    print(list_scores.mean())
# Out:
# 0.6043119821792186
# 0.6893772542125834
# 0.5291448516579407
# 0.7628235294117646

# %%
y_pred_fav_rand = fav_model_rand.predict(X_test)

#metrics for fav1 model - TEST
scores = [f1_score, precision_score, recall_score, accuracy_score]

for score in scores:
    print(score(y_test, y_pred_fav_rand))
# Out:
# 0.5924468922108574
# 0.6796028880866426
# 0.5251046025104602
# 0.756292637026582

# %%
y_pred_fav_rand_train = fav_model_rand.predict(X_train)
#metrics for fav2 model- TRAIN
scores = [f1_score, precision_score, recall_score, accuracy_score]

for score in scores:
    print(score(y_train, y_pred_fav_rand_train))
# Out:
# 0.7324920527887487
# 0.8181622552184205
# 0.6630624346006279
# 0.8366470588235294

# %%
importances = fav_model_2.feature_importances_

indices = np.argsort(importances)[::-1]

# rearrange feature names so they match the sorted feature names
# I have my original names list of feature names, which corresponds to the features in the tree.
f_names = [X.columns [i] for i in indices]

#create my plot
fig, axes = plt.subplots(figsize=(20,5))
axes.set_title("Feature Importances")
axes.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
axes.set_xticks(range(X.shape[1]));
axes.set_xticklabels(f_names, rotation=45, ha='right');
