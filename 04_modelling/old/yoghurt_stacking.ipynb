# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import xgboost as xgb
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import learning_curve, validation_curve
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

# %%
data = pd.read_csv("../02_data_preparation/yoghurt_w_dummy_data.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21251 entries, 0 to 21250
# Data columns (total 67 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 21251 non-null  int64
#  1   first_purchase             21251 non-null  bool
#  2   shelf_price                21251 non-null  float64
#  3   pct_disc                   21251 non-null  float64
#  4   pct_retail_disc            21251 non-null  float64
#  5   pct_coupon_disc            21251 non-null  float64
#  6   display_1                  21251 non-null  int64
#  7   display_2                  21251 non-null  int64
#  8   display_3                  21251 non-null  int64
#  9   display_4                  21251 non-null  int64
#  10  display_5                  21251 non-null  int64
#  11  display_6                  21251 non-null  int64
#  12  display_7                  21251 non-null  int64
#  13  display_9                  21251 non-null  int64
#  14  display_A                  21251 non-null  int64
#  15  mailer_A                   21251 non-null  int64
#  16  mailer_C                   21251 non-null  int64
#  17  mailer_D                   21251 non-null  int64
#  18  mailer_H                   21251 non-null  int64
#  19  mailer_J                   21251 non-null  int64
#  20  marital_status_A           21251 non-null  int64
#  21  marital_status_B           21251 non-null  int64
#  22  homeowner_Homeowner        21251 non-null  int64
#  23  homeowner_Probable Owner   21251 non-null  int64
#  24  homeowner_Probable Renter  21251 non-null  int64
#  25  homeowner_Renter           21251 non-null  int64
#  26  hhcomp_1 Adult Kids        21251 non-null  int64
#  27  hhcomp_2 Adults Kids       21251 non-null  int64
#  28  hhcomp_2 Adults No Kids    21251 non-null  int64
#  29  hhcomp_Single Female       21251 non-null  int64
#  30  hhcomp_Single Male         21251 non-null  int64
#  31  kid_category_1             21251 non-null  int64
#  32  kid_category_2             21251 non-null  int64
#  33  kid_category_3+            21251 non-null  int64
#  34  kid_category_None/Unknown  21251 non-null  int64
#  35  age_19-24                  21251 non-null  int64
#  36  age_25-34                  21251 non-null  int64
#  37  age_35-44                  21251 non-null  int64
#  38  age_45-54                  21251 non-null  int64
#  39  age_55-64                  21251 non-null  int64
#  40  age_65+                    21251 non-null  int64
#  41  income_100-124K            21251 non-null  int64
#  42  income_125-149K            21251 non-null  int64
#  43  income_15-24K              21251 non-null  int64
#  44  income_150-174K            21251 non-null  int64
#  45  income_175-199K            21251 non-null  int64
#  46  income_200-249K            21251 non-null  int64
#  47  income_25-34K              21251 non-null  int64
#  48  income_250K+               21251 non-null  int64
#  49  income_35-49K              21251 non-null  int64
#  50  income_50-74K              21251 non-null  int64
#  51  income_75-99K              21251 non-null  int64
#  52  income_Under 15K           21251 non-null  int64
#  53  hhsize_1                   21251 non-null  int64
#  54  hhsize_2                   21251 non-null  int64
#  55  hhsize_3                   21251 non-null  int64
#  56  hhsize_4                   21251 non-null  int64
#  57  hhsize_5+                  21251 non-null  int64
#  58  campaign_6.0               21251 non-null  int64
#  59  campaign_8.0               21251 non-null  int64
#  60  campaign_13.0              21251 non-null  int64
#  61  campaign_18.0              21251 non-null  int64
#  62  campaign_29.0              21251 non-null  int64
#  63  campaign_30.0              21251 non-null  int64
#  64  description_TypeA          21251 non-null  int64
#  65  description_TypeB          21251 non-null  int64
#  66  description_TypeC          21251 non-null  int64
# dtypes: bool(1), float64(4), int64(62)
# memory usage: 10.7 MB

# %%
data.drop(labels=["Unnamed: 0", "display_1", "display_5", "display_A", "campaign_6.0", "campaign_30.0", "description_TypeC"],
          axis = 1, inplace = True)

# %%
pd.set_option("display.max_columns", None)
data.describe(include = "all")
# Out:
#        first_purchase   shelf_price      pct_disc  pct_retail_disc  \
# count           21251  21251.000000  21251.000000     21251.000000
# unique              2           NaN           NaN              NaN
# top             False           NaN           NaN              NaN
# freq            14083           NaN           NaN              NaN
# mean              NaN      1.156933      0.158316         0.153330
# std               NaN      1.104681      0.145841         0.137543
# min               NaN      0.350000      0.000000        -0.000000
# 25%               NaN      0.400000      0.000000        -0.000000
# 50%               NaN      0.790000      0.166667         0.163180
# 75%               NaN      0.790000      0.240506         0.240506
# max               NaN      6.590000      0.909091         0.702341
#
#         pct_coupon_disc     display_2     display_3     display_4  \
# count      21251.000000  21251.000000  21251.000000  21251.000000
# unique              NaN           NaN           NaN           NaN
# top                 NaN           NaN           NaN           NaN
# freq                NaN           NaN           NaN           NaN
# mean           0.004987      0.011152      0.007623      0.001082
# std            0.044610      0.105017      0.086979      0.032881
# min           -0.000000      0.000000      0.000000      0.000000
# 25%           -0.000000      0.000000      0.000000      0.000000
# 50%            0.000000      0.000000      0.000000      0.000000
# 75%           -0.000000      0.000000      0.000000      0.000000
# max            0.909091      1.000000      1.000000      1.000000
#
#            display_6     display_7     display_9      mailer_A      mailer_C  \
# count   21251.000000  21251.000000  21251.000000  21251.000000  21251.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.005459      0.012046      0.004047      0.148699      0.001223
# std         0.073682      0.109096      0.063488      0.355800      0.034958
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.000000      0.000000      0.000000      0.000000      0.000000
# 50%         0.000000      0.000000      0.000000      0.000000      0.000000
# 75%         0.000000      0.000000      0.000000      0.000000      0.000000
# max         1.000000      1.000000      1.000000      1.000000      1.000000
#
#             mailer_D      mailer_H      mailer_J  marital_status_A  \
# count   21251.000000  21251.000000  21251.000000      21251.000000
# unique           NaN           NaN           NaN               NaN
# top              NaN           NaN           NaN               NaN
# freq             NaN           NaN           NaN               NaN
# mean        0.048751      0.008235      0.005270          0.488918
# std         0.215351      0.090374      0.072407          0.499889
# min         0.000000      0.000000      0.000000          0.000000
# 25%         0.000000      0.000000      0.000000          0.000000
# 50%         0.000000      0.000000      0.000000          0.000000
# 75%         0.000000      0.000000      0.000000          1.000000
# max         1.000000      1.000000      1.000000          1.000000
#
#         marital_status_B  homeowner_Homeowner  homeowner_Probable Owner  \
# count       21251.000000         21251.000000              21251.000000
# unique               NaN                  NaN                       NaN
# top                  NaN                  NaN                       NaN
# freq                 NaN                  NaN                       NaN
# mean            0.125406             0.686321                  0.015152
# std             0.331186             0.463999                  0.122161
# min             0.000000             0.000000                  0.000000
# 25%             0.000000             0.000000                  0.000000
# 50%             0.000000             1.000000                  0.000000
# 75%             0.000000             1.000000                  0.000000
# max             1.000000             1.000000                  1.000000
#
#         homeowner_Probable Renter  homeowner_Renter  hhcomp_1 Adult Kids  \
# count                21251.000000      21251.000000         21251.000000
# unique                        NaN               NaN                  NaN
# top                           NaN               NaN                  NaN
# freq                          NaN               NaN                  NaN
# mean                     0.005176          0.037834             0.061974
# std                      0.071761          0.190798             0.241113
# min                      0.000000          0.000000             0.000000
# 25%                      0.000000          0.000000             0.000000
# 50%                      0.000000          0.000000             0.000000
# 75%                      0.000000          0.000000             0.000000
# max                      1.000000          1.000000             1.000000
#
#         hhcomp_2 Adults Kids  hhcomp_2 Adults No Kids  hhcomp_Single Female  \
# count           21251.000000             21251.000000          21251.000000
# unique                   NaN                      NaN                   NaN
# top                      NaN                      NaN                   NaN
# freq                     NaN                      NaN                   NaN
# mean                0.295092                 0.314009              0.147711
# std                 0.456095                 0.464131              0.354821
# min                 0.000000                 0.000000              0.000000
# 25%                 0.000000                 0.000000              0.000000
# 50%                 0.000000                 0.000000              0.000000
# 75%                 1.000000                 1.000000              0.000000
# max                 1.000000                 1.000000              1.000000
#
#         hhcomp_Single Male  kid_category_1  kid_category_2  kid_category_3+  \
# count         21251.000000    21251.000000    21251.000000     21251.000000
# unique                 NaN             NaN             NaN              NaN
# top                    NaN             NaN             NaN              NaN
# freq                   NaN             NaN             NaN              NaN
# mean              0.122677        0.159240        0.098537         0.102254
# std               0.328073        0.365908        0.298046         0.302989
# min               0.000000        0.000000        0.000000         0.000000
# 25%               0.000000        0.000000        0.000000         0.000000
# 50%               0.000000        0.000000        0.000000         0.000000
# 75%               0.000000        0.000000        0.000000         0.000000
# max               1.000000        1.000000        1.000000         1.000000
#
#         kid_category_None/Unknown     age_19-24     age_25-34     age_35-44  \
# count                 21251.00000  21251.000000  21251.000000  21251.000000
# unique                        NaN           NaN           NaN           NaN
# top                           NaN           NaN           NaN           NaN
# freq                          NaN           NaN           NaN           NaN
# mean                      0.63997      0.042727      0.211896      0.276975
# std                       0.48002      0.202247      0.408661      0.447515
# min                       0.00000      0.000000      0.000000      0.000000
# 25%                       0.00000      0.000000      0.000000      0.000000
# 50%                       1.00000      0.000000      0.000000      0.000000
# 75%                       1.00000      0.000000      0.000000      1.000000
# max                       1.00000      1.000000      1.000000      1.000000
#
#            age_45-54     age_55-64       age_65+  income_100-124K  \
# count   21251.000000  21251.000000  21251.000000     21251.000000
# unique           NaN           NaN           NaN              NaN
# top              NaN           NaN           NaN              NaN
# freq             NaN           NaN           NaN              NaN
# mean        0.347701      0.067009      0.053692         0.080420
# std         0.476252      0.250043      0.225413         0.271948
# min         0.000000      0.000000      0.000000         0.000000
# 25%         0.000000      0.000000      0.000000         0.000000
# 50%         0.000000      0.000000      0.000000         0.000000
# 75%         1.000000      0.000000      0.000000         0.000000
# max         1.000000      1.000000      1.000000         1.000000
#
#         income_125-149K  income_15-24K  income_150-174K  income_175-199K  \
# count      21251.000000   21251.000000     21251.000000     21251.000000
# unique              NaN            NaN              NaN              NaN
# top                 NaN            NaN              NaN              NaN
# freq                NaN            NaN              NaN              NaN
# mean           0.074820       0.054586         0.085972         0.017646
# std            0.263107       0.227175         0.280330         0.131665
# min            0.000000       0.000000         0.000000         0.000000
# 25%            0.000000       0.000000         0.000000         0.000000
# 50%            0.000000       0.000000         0.000000         0.000000
# 75%            0.000000       0.000000         0.000000         0.000000
# max            1.000000       1.000000         1.000000         1.000000
#
#         income_200-249K  income_25-34K  income_250K+  income_35-49K  \
# count      21251.000000   21251.000000  21251.000000   21251.000000
# unique              NaN            NaN           NaN            NaN
# top                 NaN            NaN           NaN            NaN
# freq                NaN            NaN           NaN            NaN
# mean           0.006870       0.079384      0.017646       0.180086
# std            0.082604       0.270344      0.131665       0.384268
# min            0.000000       0.000000      0.000000       0.000000
# 25%            0.000000       0.000000      0.000000       0.000000
# 50%            0.000000       0.000000      0.000000       0.000000
# 75%            0.000000       0.000000      0.000000       0.000000
# max            1.000000       1.000000      1.000000       1.000000
#
#         income_50-74K  income_75-99K  income_Under 15K      hhsize_1  \
# count    21251.000000   21251.000000      21251.000000  21251.000000
# unique            NaN            NaN               NaN           NaN
# top               NaN            NaN               NaN           NaN
# freq              NaN            NaN               NaN           NaN
# mean         0.224037       0.126394          0.052139      0.280975
# std          0.416956       0.332301          0.222312      0.449486
# min          0.000000       0.000000          0.000000      0.000000
# 25%          0.000000       0.000000          0.000000      0.000000
# 50%          0.000000       0.000000          0.000000      0.000000
# 75%          0.000000       0.000000          0.000000      1.000000
# max          1.000000       1.000000          1.000000      1.000000
#
#             hhsize_2      hhsize_3      hhsize_4     hhsize_5+  campaign_8.0  \
# count   21251.000000  21251.000000  21251.000000  21251.000000  21251.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.374476      0.156746      0.089596      0.098207      0.076373
# std         0.483999      0.363569      0.285609      0.297602      0.265600
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.000000      0.000000      0.000000      0.000000      0.000000
# 50%         0.000000      0.000000      0.000000      0.000000      0.000000
# 75%         1.000000      0.000000      0.000000      0.000000      0.000000
# max         1.000000      1.000000      1.000000      1.000000      1.000000
#
#         campaign_13.0  campaign_18.0  campaign_29.0  description_TypeA  \
# count    21251.000000   21251.000000   21251.000000       21251.000000
# unique            NaN            NaN            NaN                NaN
# top               NaN            NaN            NaN                NaN
# freq              NaN            NaN            NaN                NaN
# mean         0.077879       0.075855       0.006776           0.230248
# std          0.267987       0.264773       0.082040           0.421001
# min          0.000000       0.000000       0.000000           0.000000
# 25%          0.000000       0.000000       0.000000           0.000000
# 50%          0.000000       0.000000       0.000000           0.000000
# 75%          0.000000       0.000000       0.000000           0.000000
# max          1.000000       1.000000       1.000000           1.000000
#
#         description_TypeB
# count        21251.000000
# unique                NaN
# top                   NaN
# freq                  NaN
# mean             0.006776
# std              0.082040
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.000000
# max              1.000000

# %%
X = data.drop("first_purchase", axis = 1)
y = data["first_purchase"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8, stratify = y)

# %%
cv = StratifiedShuffleSplit(n_splits = 5)

# %% [markdown]
# #Stacking the models

# %%
estimators = [
    ("rf_3", RandomForestClassifier(n_jobs = -1, class_weight = "balanced",
                             max_depth = 20, max_samples = 0.7, min_samples_split = 6, n_estimators = 250, random_state = 42)),
    ("xgb_2", xgb.XGBClassifier(scale_pos_weight = 1.965, colsample_bytree = 0.6, colsample_bynode = 0.8, colsample_bylevel = 0.5, 
                                max_delta_step = 1, tree_method = "hist", objective = "binary:logistic",
                         alpha = 1, reg_lambda = 2, learning_rate = 0.2, max_depth = 14, min_child_weight = 3,
                         n_estimators = 300, subsample = 0.8, random_state = 42)),
    ("lgbm_5", lgb.LGBMClassifier(objective = "binary", is_unbalance = True, max_depth = 9, colsample_bytree = 0.8,
                             learning_rate= 0.5,  max_bin= 25,  min_child_samples= 50,  n_estimators= 400, 
                             num_leaves= 70,  reg_alpha= 1, boosting_type = "gbdt", subsample = 0.7, subsample_freq = 2, random_state =42)),
    ("lgbm_unbalanced", lgb.LGBMClassifier(objective = "binary", max_depth = 9, 
                                      boosting_type = 'gbdt', colsample_bytree = 0.8, learning_rate= 0.5,  max_bin= 40, 
                                      min_child_samples= 50,  n_estimators= 400, num_leaves= 70,  reg_alpha= 0, random_state =42))]

# %%
estimators_all = [
    ("clf_fav_model_balanced", DecisionTreeClassifier(ccp_alpha= 1e-05,  criterion= 'entropy',  max_depth= 25,  min_impurity_decrease= 3e-06, 
                                            min_samples_leaf= 1,  min_samples_split= 6, class_weight = "balanced", random_state = 42)),
    ("rf_3", RandomForestClassifier(n_jobs = -1, class_weight = "balanced",
                             max_depth = 20, max_samples = 0.7, min_samples_split = 6, n_estimators = 250, random_state = 42)),
    ("rf_unbalanced", RandomForestClassifier(n_jobs = -1, 
                             max_depth = 30, max_samples = 0.7, min_samples_split = 6, n_estimators = 250, random_state = 42)),
    ("xgb_2", xgb.XGBClassifier(scale_pos_weight = 1.965, colsample_bytree = 0.6, colsample_bynode = 0.8, colsample_bylevel = 0.5, 
                                max_delta_step = 1, tree_method = "hist", objective = "binary:logistic",
                         alpha = 1, reg_lambda = 2, learning_rate = 0.2, max_depth = 14, min_child_weight = 3,
                         n_estimators = 300, subsample = 0.8, random_state = 42)),
    ("xgb_2_unbalanced", xgb.XGBClassifier(colsample_bytree = 0.6, colsample_bynode = 0.8, colsample_bylevel = 0.5, 
                                max_delta_step = 1, tree_method = "hist", objective = "binary:logistic",
                         alpha = 0, reg_lambda = 7, learning_rate = 0.2, max_depth = 14, min_child_weight = 3,
                         n_estimators = 400, subsample = 0.8, random_state = 42)),
    ("lgbm_5", lgb.LGBMClassifier(objective = "binary", is_unbalance = True, max_depth = 9, colsample_bytree = 0.8,
                             learning_rate= 0.5,  max_bin= 25,  min_child_samples= 50,  n_estimators= 400, 
                             num_leaves= 70,  reg_alpha= 1, boosting_type = "gbdt", subsample = 0.7, subsample_freq = 2, random_state =42)),
    ("lgbm_unbalanced", lgb.LGBMClassifier(objective = "binary", max_depth = 9, 
                                      boosting_type = 'gbdt', colsample_bytree = 0.8, learning_rate= 0.5,  max_bin= 40, 
                                      min_child_samples= 50,  n_estimators= 400, num_leaves= 70,  reg_alpha= 0, random_state =42))]

# %%
stacked = StackingClassifier(estimators = estimators_all, n_jobs = -1, final_estimator = lgb.LGBMClassifier(), cv=5)

# %%
stacked.fit(X_train, y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('clf_fav_model_balanced',
#                                 DecisionTreeClassifier(ccp_alpha=1e-05,
#                                                        class_weight='balanced',
#                                                        criterion='entropy',
#                                                        max_depth=25,
#                                                        min_impurity_decrease=3e-06,
#                                                        min_samples_split=6,
#                                                        random_state=42)),
#                                ('rf_3',
#                                 RandomForestClassifier(class_weight='balanced',
#                                                        max_depth=20,
#                                                        max_samples=0.7,
#                                                        min_samples_split=6,
#                                                        n_estimators=250,
#                                                        n_job...
#                                                n_estimators=400, num_leaves=70,
#                                                objective='binary',
#                                                random_state=42, reg_alpha=1,
#                                                subsample=0.7,
#                                                subsample_freq=2)),
#                                ('lgbm_unbalanced',
#                                 LGBMClassifier(colsample_bytree=0.8,
#                                                learning_rate=0.5, max_bin=40,
#                                                max_depth=9,
#                                                min_child_samples=50,
#                                                n_estimators=400, num_leaves=70,
#                                                objective='binary',
#                                                random_state=42, reg_alpha=0))],
#                    final_estimator=LGBMClassifier(), n_jobs=-1)

# %%
y_pred_stacked = stacked.predict(X_test)
#metrics for stacked model - TEST
scores = [f1_score, precision_score, recall_score, accuracy_score]

for score in scores:
    print(score(y_test, y_pred_stacked))
# Out:
# 0.629872636047858
# 0.7052722558340536
# 0.5690376569037657
# 0.7744060221124441

# %% [markdown]
# #Tune hyperparameters of StackingClassifier

# %%
params_stack = {
    "final_estimator": [RandomForestClassifier(), xgb.XGBClassifier(), lgb.LGBMClassifier()],
    "stack_method": ["auto", "predict_proba", "decision_function", "predict"],
    "passthrough": [True, False]}

# %%
stack = StackingClassifier(estimators = estimators_all, n_jobs = -1, cv=5)

# %%
grid_search_stack = GridSearchCV(stack, param_grid= params_stack, cv=cv, scoring = "f1")
grid_search_stack.fit(X_train, y_train)
# Out:
# C:\Users\Gabriele\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 30 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Gabriele\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Gabriele\anaconda3\lib\site-packages\sklearn\ensemble\_stacking.py", line 488, in fit
#     return super().fit(X, self._le.transform(y), sample_weight)
#   File "C:\Users\Gabriele\anaconda3\lib\site-packages\sklearn\ensemble\_stacking.py", line 186, in fit
#     self.stack_method_ = [
#   File "C:\Users\Gabriele\anaconda3\lib\site-packages\sklearn\ensemble\_stacking.py", line 187, in <listcomp>
#     self._method_name(name, est, meth)
#   File "C:\Users\Gabriele\anaconda3\lib\site-packages\sklearn\ensemble\_stacking.py", line 116, in _method_name
#     raise ValueError(
# ValueError: Underlying estimator clf_fav_model_balanced does not implement the method decision_function.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Gabriele\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.62257968 0.62563649        nan 0.59679402 0.60854799 0.61987538
#         nan 0.62274291 0.60413762 0.60413762        nan 0.60195577
#  0.60479899 0.60479899        nan 0.62324276 0.61136    0.61136
#         nan 0.62186799 0.60567183 0.60567183        nan 0.62390985]
#   warnings.warn(
# GridSearchCV(cv=StratifiedShuffleSplit(n_splits=5,
#             random_state=RandomState(MT19937) at 0x1B6B5BEC240,
#             test_size=None, train_size=None),
#              estimator=StackingClassifier(cv=5,
#                                           estimators=[('clf_fav_model_balanced',
#                                                        DecisionTreeClassifier(ccp_alpha=1e-05,
#                                                                               class_weight='balanced',
#                                                                               criterion='entropy',
#                                                                               max_depth=25,
#                                                                               min_impurity_decrease=3e-06,
#                                                                               min_samples_split=6,
#                                                                               ran...
#                                                            max_cat_to_onehot=None,
#                                                            max_delta_step=None,
#                                                            max_depth=None,
#                                                            max_leaves=None,
#                                                            min_child_weight=None,
#                                                            missing=nan,
#                                                            monotone_constraints=None,
#                                                            n_estimators=100,
#                                                            n_jobs=None,
#                                                            num_parallel_tree=None,
#                                                            predictor=None,
#                                                            random_state=None, ...),
#                                              LGBMClassifier()],
#                          'passthrough': [True, False],
#                          'stack_method': ['auto', 'predict_proba',
#                                           'decision_function', 'predict']},
#              scoring='f1')

# %%
grid_search_stack.best_score_
# Out:
# 0.6256364936847854

# %%
grid_search_stack.best_params_
# Out:
# {'final_estimator': RandomForestClassifier(),
#  'passthrough': True,
#  'stack_method': 'predict_proba'}

# %%
grid_search_stack.cv_results_
# Out:
# {'mean_fit_time': array([54.91280947, 54.71522331, 10.49612365, 56.15151343, 56.49102201,
#         57.38010545, 11.06199951, 53.53681369, 56.6400394 , 56.79758697,
#         11.2613102 , 57.63636241, 54.8093956 , 57.59791374, 11.11328454,
#         54.95304222, 55.61040692, 55.68891439, 13.71685557, 48.14445677,
#         55.11614347, 55.14280353, 11.9082283 , 54.76751223]),
#  'std_fit_time': array([4.95379624, 2.10120493, 0.33592571, 4.16048258, 3.04701095,
#         2.51626131, 0.23434804, 1.11271841, 0.66279753, 1.438665  ,
#         0.35661043, 3.8096032 , 1.37107939, 0.79763283, 0.53965937,
#         1.55717878, 1.69009574, 2.94692332, 3.34267798, 1.40190892,
#         1.66945578, 1.34420848, 0.61715717, 1.64447641]),
#  'mean_score_time': array([0.57377253, 0.52535501, 0.        , 0.49822593, 0.49706545,
#         0.52985849, 0.        , 0.56939054, 0.49702339, 0.53111811,
#         0.        , 0.57145519, 0.56205854, 0.62328544, 0.        ,
#         0.5970408 , 0.6398479 , 0.65181503, 0.        , 0.47793932,
#         0.51967187, 0.56028104, 0.        , 0.61328144]),
#  'std_score_time': array([0.18910186, 0.09872766, 0.        , 0.07597254, 0.01474218,
#         0.06106139, 0.        , 0.03791749, 0.03497756, 0.05326567,
#         0.        , 0.07417543, 0.0240628 , 0.06755491, 0.        ,
#         0.03014006, 0.04979108, 0.04429047, 0.        , 0.01634654,
#         0.02932607, 0.0826069 , 0.        , 0.12223513]),
#  'param_final_estimator': masked_array(data=[RandomForestClassifier(), RandomForestClassifier(),
#                     RandomForestClassifier(), RandomForestClassifier(),
#                     RandomForestClassifier(), RandomForestClassifier(),
#                     RandomForestClassifier(), RandomForestClassifier(),
#                     XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                   colsample_bylevel=None, colsample_bynode=None,
#                                   colsample_bytree=None, early_stopping_rounds=None,
#                                   enable_categorical=False, eval_metric=None, feature_types=None,
#                                   gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                                   interaction_constraints=None, learning_rate=None, max_bin=None,
#                                   max_cat_threshold=None, max_cat_to_onehot=None,
#                                   max_delta_step=None, max_depth=None, max_leaves=None,
#                                   min_child_weight=None, missing=nan, monotone_constraints=None,
#                                   n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                                   predictor=None, random_state=None, ...)                         ,
#                     XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                   colsample_bylevel=None, colsample_bynode=None,
#                                   colsample_bytree=None, early_stopping_rounds=None,
#                                   enable_categorical=False, eval_metric=None, feature_types=None,
#                                   gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                                   interaction_constraints=None, learning_rate=None, max_bin=None,
#                                   max_cat_threshold=None, max_cat_to_onehot=None,
#                                   max_delta_step=None, max_depth=None, max_leaves=None,
#                                   min_child_weight=None, missing=nan, monotone_constraints=None,
#                                   n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                                   predictor=None, random_state=None, ...)                         ,
#                     XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                   colsample_bylevel=None, colsample_bynode=None,
#                                   colsample_bytree=None, early_stopping_rounds=None,
#                                   enable_categorical=False, eval_metric=None, feature_types=None,
#                                   gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                                   interaction_constraints=None, learning_rate=None, max_bin=None,
#                                   max_cat_threshold=None, max_cat_to_onehot=None,
#                                   max_delta_step=None, max_depth=None, max_leaves=None,
#                                   min_child_weight=None, missing=nan, monotone_constraints=None,
#                                   n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                                   predictor=None, random_state=None, ...)                         ,
#                     XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                   colsample_bylevel=None, colsample_bynode=None,
#                                   colsample_bytree=None, early_stopping_rounds=None,
#                                   enable_categorical=False, eval_metric=None, feature_types=None,
#                                   gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                                   interaction_constraints=None, learning_rate=None, max_bin=None,
#                                   max_cat_threshold=None, max_cat_to_onehot=None,
#                                   max_delta_step=None, max_depth=None, max_leaves=None,
#                                   min_child_weight=None, missing=nan, monotone_constraints=None,
#                                   n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                                   predictor=None, random_state=None, ...)                         ,
#                     XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                   colsample_bylevel=None, colsample_bynode=None,
#                                   colsample_bytree=None, early_stopping_rounds=None,
#                                   enable_categorical=False, eval_metric=None, feature_types=None,
#                                   gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                                   interaction_constraints=None, learning_rate=None, max_bin=None,
#                                   max_cat_threshold=None, max_cat_to_onehot=None,
#                                   max_delta_step=None, max_depth=None, max_leaves=None,
#                                   min_child_weight=None, missing=nan, monotone_constraints=None,
#                                   n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                                   predictor=None, random_state=None, ...)                         ,
#                     XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                   colsample_bylevel=None, colsample_bynode=None,
#                                   colsample_bytree=None, early_stopping_rounds=None,
#                                   enable_categorical=False, eval_metric=None, feature_types=None,
#                                   gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                                   interaction_constraints=None, learning_rate=None, max_bin=None,
#                                   max_cat_threshold=None, max_cat_to_onehot=None,
#                                   max_delta_step=None, max_depth=None, max_leaves=None,
#                                   min_child_weight=None, missing=nan, monotone_constraints=None,
#                                   n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                                   predictor=None, random_state=None, ...)                         ,
#                     XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                   colsample_bylevel=None, colsample_bynode=None,
#                                   colsample_bytree=None, early_stopping_rounds=None,
#                                   enable_categorical=False, eval_metric=None, feature_types=None,
#                                   gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                                   interaction_constraints=None, learning_rate=None, max_bin=None,
#                                   max_cat_threshold=None, max_cat_to_onehot=None,
#                                   max_delta_step=None, max_depth=None, max_leaves=None,
#                                   min_child_weight=None, missing=nan, monotone_constraints=None,
#                                   n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                                   predictor=None, random_state=None, ...)                         ,
#                     XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                   colsample_bylevel=None, colsample_bynode=None,
#                                   colsample_bytree=None, early_stopping_rounds=None,
#                                   enable_categorical=False, eval_metric=None, feature_types=None,
#                                   gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                                   interaction_constraints=None, learning_rate=None, max_bin=None,
#                                   max_cat_threshold=None, max_cat_to_onehot=None,
#                                   max_delta_step=None, max_depth=None, max_leaves=None,
#                                   min_child_weight=None, missing=nan, monotone_constraints=None,
#                                   n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                                   predictor=None, random_state=None, ...)                         ,
#                     LGBMClassifier(), LGBMClassifier(), LGBMClassifier(),
#                     LGBMClassifier(), LGBMClassifier(), LGBMClassifier(),
#                     LGBMClassifier(), LGBMClassifier()],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_passthrough': masked_array(data=[True, True, True, True, False, False, False, False,
#                     True, True, True, True, False, False, False, False,
#                     True, True, True, True, False, False, False, False],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_stack_method': masked_array(data=['auto', 'predict_proba', 'decision_function',
#                     'predict', 'auto', 'predict_proba',
#                     'decision_function', 'predict', 'auto',
#                     'predict_proba', 'decision_function', 'predict',
#                     'auto', 'predict_proba', 'decision_function',
#                     'predict', 'auto', 'predict_proba',
#                     'decision_function', 'predict', 'auto',
#                     'predict_proba', 'decision_function', 'predict'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'final_estimator': RandomForestClassifier(),
#    'passthrough': True,
#    'stack_method': 'auto'},
#   {'final_estimator': RandomForestClassifier(),
#    'passthrough': True,
#    'stack_method': 'predict_proba'},
#   {'final_estimator': RandomForestClassifier(),
#    'passthrough': True,
#    'stack_method': 'decision_function'},
#   {'final_estimator': RandomForestClassifier(),
#    'passthrough': True,
#    'stack_method': 'predict'},
#   {'final_estimator': RandomForestClassifier(),
#    'passthrough': False,
#    'stack_method': 'auto'},
#   {'final_estimator': RandomForestClassifier(),
#    'passthrough': False,
#    'stack_method': 'predict_proba'},
#   {'final_estimator': RandomForestClassifier(),
#    'passthrough': False,
#    'stack_method': 'decision_function'},
#   {'final_estimator': RandomForestClassifier(),
#    'passthrough': False,
#    'stack_method': 'predict'},
#   {'final_estimator': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric=None, feature_types=None,
#                  gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                  interaction_constraints=None, learning_rate=None, max_bin=None,
#                  max_cat_threshold=None, max_cat_to_onehot=None,
#                  max_delta_step=None, max_depth=None, max_leaves=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                  predictor=None, random_state=None, ...),
#    'passthrough': True,
#    'stack_method': 'auto'},
#   {'final_estimator': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric=None, feature_types=None,
#                  gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                  interaction_constraints=None, learning_rate=None, max_bin=None,
#                  max_cat_threshold=None, max_cat_to_onehot=None,
#                  max_delta_step=None, max_depth=None, max_leaves=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                  predictor=None, random_state=None, ...),
#    'passthrough': True,
#    'stack_method': 'predict_proba'},
#   {'final_estimator': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric=None, feature_types=None,
#                  gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                  interaction_constraints=None, learning_rate=None, max_bin=None,
#                  max_cat_threshold=None, max_cat_to_onehot=None,
#                  max_delta_step=None, max_depth=None, max_leaves=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                  predictor=None, random_state=None, ...),
#    'passthrough': True,
#    'stack_method': 'decision_function'},
#   {'final_estimator': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric=None, feature_types=None,
#                  gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                  interaction_constraints=None, learning_rate=None, max_bin=None,
#                  max_cat_threshold=None, max_cat_to_onehot=None,
#                  max_delta_step=None, max_depth=None, max_leaves=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                  predictor=None, random_state=None, ...),
#    'passthrough': True,
#    'stack_method': 'predict'},
#   {'final_estimator': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric=None, feature_types=None,
#                  gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                  interaction_constraints=None, learning_rate=None, max_bin=None,
#                  max_cat_threshold=None, max_cat_to_onehot=None,
#                  max_delta_step=None, max_depth=None, max_leaves=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                  predictor=None, random_state=None, ...),
#    'passthrough': False,
#    'stack_method': 'auto'},
#   {'final_estimator': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric=None, feature_types=None,
#                  gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                  interaction_constraints=None, learning_rate=None, max_bin=None,
#                  max_cat_threshold=None, max_cat_to_onehot=None,
#                  max_delta_step=None, max_depth=None, max_leaves=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                  predictor=None, random_state=None, ...),
#    'passthrough': False,
#    'stack_method': 'predict_proba'},
#   {'final_estimator': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric=None, feature_types=None,
#                  gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                  interaction_constraints=None, learning_rate=None, max_bin=None,
#                  max_cat_threshold=None, max_cat_to_onehot=None,
#                  max_delta_step=None, max_depth=None, max_leaves=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                  predictor=None, random_state=None, ...),
#    'passthrough': False,
#    'stack_method': 'decision_function'},
#   {'final_estimator': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric=None, feature_types=None,
#                  gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                  interaction_constraints=None, learning_rate=None, max_bin=None,
#                  max_cat_threshold=None, max_cat_to_onehot=None,
#                  max_delta_step=None, max_depth=None, max_leaves=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                  predictor=None, random_state=None, ...),
#    'passthrough': False,
#    'stack_method': 'predict'},
#   {'final_estimator': LGBMClassifier(),
#    'passthrough': True,
#    'stack_method': 'auto'},
#   {'final_estimator': LGBMClassifier(),
#    'passthrough': True,
#    'stack_method': 'predict_proba'},
#   {'final_estimator': LGBMClassifier(),
#    'passthrough': True,
#    'stack_method': 'decision_function'},
#   {'final_estimator': LGBMClassifier(),
#    'passthrough': True,
#    'stack_method': 'predict'},
#   {'final_estimator': LGBMClassifier(),
#    'passthrough': False,
#    'stack_method': 'auto'},
#   {'final_estimator': LGBMClassifier(),
#    'passthrough': False,
#    'stack_method': 'predict_proba'},
#   {'final_estimator': LGBMClassifier(),
#    'passthrough': False,
#    'stack_method': 'decision_function'},
#   {'final_estimator': LGBMClassifier(),
#    'passthrough': False,
#    'stack_method': 'predict'}],
#  'split0_test_score': array([0.61748634, 0.62602366,        nan, 0.61266294, 0.59539171,
#         0.60092166,        nan, 0.61308411, 0.60150376, 0.60150376,
#                nan, 0.5879017 , 0.60093897, 0.60093897,        nan,
#         0.61308411, 0.61410019, 0.61410019,        nan, 0.61865189,
#         0.61095636, 0.61095636,        nan, 0.61509786]),
#  'split1_test_score': array([0.66850321, 0.65004617,        nan, 0.60205033, 0.62797336,
#         0.64119292,        nan, 0.64794007, 0.63187856, 0.63187856,
#                nan, 0.62114125, 0.62547529, 0.62547529,        nan,
#         0.64727955, 0.63288719, 0.63288719,        nan, 0.64007421,
#         0.61969112, 0.61969112,        nan, 0.64716981]),
#  'split2_test_score': array([0.59244918, 0.61787072,        nan, 0.60151803, 0.6091954 ,
#         0.62055716,        nan, 0.61271676, 0.59528487, 0.59528487,
#                nan, 0.59069326, 0.58292444, 0.58292444,        nan,
#         0.61271676, 0.59288538, 0.59288538,        nan, 0.60936008,
#         0.59171598, 0.59171598,        nan, 0.61287224]),
#  'split3_test_score': array([0.6221374 , 0.61698113,        nan, 0.58979206, 0.61290323,
#         0.62146893,        nan, 0.60395108, 0.58949416, 0.58949416,
#                nan, 0.59698682, 0.61196911, 0.61196911,        nan,
#         0.60583255, 0.61062802, 0.61062802,        nan, 0.61220657,
#         0.61845861, 0.61845861,        nan, 0.60583255]),
#  'split4_test_score': array([0.61232227, 0.61726079,        nan, 0.57794677, 0.59727626,
#         0.61523626,        nan, 0.63602251, 0.60252672, 0.60252672,
#                nan, 0.61305582, 0.60268714, 0.60268714,        nan,
#         0.63730084, 0.60629921, 0.60629921,        nan, 0.62904718,
#         0.58753709, 0.58753709,        nan, 0.63857678]),
#  'mean_test_score': array([0.62257968, 0.62563649,        nan, 0.59679402, 0.60854799,
#         0.61987538,        nan, 0.62274291, 0.60413762, 0.60413762,
#                nan, 0.60195577, 0.60479899, 0.60479899,        nan,
#         0.62324276, 0.61136   , 0.61136   ,        nan, 0.62186799,
#         0.60567183, 0.60567183,        nan, 0.62390985]),
#  'std_test_score': array([0.02509251, 0.01265983,        nan, 0.01188288, 0.01180569,
#         0.01294764,        nan, 0.01648147, 0.01464168, 0.01464168,
#                nan, 0.01296415, 0.01397695, 0.01397695,        nan,
#         0.01607798, 0.01294904, 0.01294904,        nan, 0.01134144,
#         0.01350262, 0.01350262,        nan, 0.01601508]),
#  'rank_test_score': array([ 5,  1, 23, 18, 10,  7, 22,  4, 15, 15, 21, 17, 13, 13, 24,  3,  8,
#          8, 20,  6, 11, 11, 19,  2])}

# %%
stack_1 = StackingClassifier(estimators = estimators_all, n_jobs = -1, cv=5, 
                            final_estimator= RandomForestClassifier(), passthrough = True, stack_method = "predict_proba")

# %%
stack_1.fit(X_train, y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('clf_fav_model_balanced',
#                                 DecisionTreeClassifier(ccp_alpha=1e-05,
#                                                        class_weight='balanced',
#                                                        criterion='entropy',
#                                                        max_depth=25,
#                                                        min_impurity_decrease=3e-06,
#                                                        min_samples_split=6,
#                                                        random_state=42)),
#                                ('rf_3',
#                                 RandomForestClassifier(class_weight='balanced',
#                                                        max_depth=20,
#                                                        max_samples=0.7,
#                                                        min_samples_split=6,
#                                                        n_estimators=250,
#                                                        n_job...
#                                                random_state=42, reg_alpha=1,
#                                                subsample=0.7,
#                                                subsample_freq=2)),
#                                ('lgbm_unbalanced',
#                                 LGBMClassifier(colsample_bytree=0.8,
#                                                learning_rate=0.5, max_bin=40,
#                                                max_depth=9,
#                                                min_child_samples=50,
#                                                n_estimators=400, num_leaves=70,
#                                                objective='binary',
#                                                random_state=42, reg_alpha=0))],
#                    final_estimator=RandomForestClassifier(), n_jobs=-1,
#                    passthrough=True, stack_method='predict_proba')

# %%
y_pred_stack_1 = stack_1.predict(X_test)
#metrics for stack_1 model - TEST
scores = [f1_score, precision_score, recall_score, accuracy_score]

for score in scores:
    print(score(y_test, y_pred_stack_1))
# Out:
# 0.6319758672699849
# 0.6880131362889984
# 0.5843793584379359
# 0.7704069630675136

# %%
stack_2 = StackingClassifier(estimators = estimators_all, n_jobs = -1, cv=5, 
                            final_estimator= lgb.LGBMClassifier(), passthrough = False, stack_method = "predict")

# %%
stack_2.fit(X_train, y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('clf_fav_model_balanced',
#                                 DecisionTreeClassifier(ccp_alpha=1e-05,
#                                                        class_weight='balanced',
#                                                        criterion='entropy',
#                                                        max_depth=25,
#                                                        min_impurity_decrease=3e-06,
#                                                        min_samples_split=6,
#                                                        random_state=42)),
#                                ('rf_3',
#                                 RandomForestClassifier(class_weight='balanced',
#                                                        max_depth=20,
#                                                        max_samples=0.7,
#                                                        min_samples_split=6,
#                                                        n_estimators=250,
#                                                        n_job...
#                                                n_estimators=400, num_leaves=70,
#                                                objective='binary',
#                                                random_state=42, reg_alpha=1,
#                                                subsample=0.7,
#                                                subsample_freq=2)),
#                                ('lgbm_unbalanced',
#                                 LGBMClassifier(colsample_bytree=0.8,
#                                                learning_rate=0.5, max_bin=40,
#                                                max_depth=9,
#                                                min_child_samples=50,
#                                                n_estimators=400, num_leaves=70,
#                                                objective='binary',
#                                                random_state=42, reg_alpha=0))],
#                    final_estimator=LGBMClassifier(), n_jobs=-1,
#                    stack_method='predict')

# %%
y_pred_stack_2 = stack_2.predict(X_test)
#metrics for stack_2 model - TEST
scores = [f1_score, precision_score, recall_score, accuracy_score]

for score in scores:
    print(score(y_test, y_pred_stack_2))
# Out:
# 0.6240120436582611
# 0.6778413736713
# 0.5781032078103208
# 0.7649964714184898

# %% [markdown]
# ## Tune initial simple model stacked

# %%
import scipy

# %%
rand_params_stacked = {'final_estimator__max_depth': scipy.stats.randint(5,30), "final_estimator__subsample": np.arange(0.6,1,0.1), 
                       "final_estimator__colsample_bytree": np.arange(0.6,1,0.1), 
                       "final_estimator__n_estimators": scipy.stats.randint(50, 250), 
                       "final_estimator__learning_rate": np.arange(0.05,0.3,0.05), "final_estimator__num_leaves": scipy.stats.randint(5,50), 
                       "final_estimator__boosting_type" : ["gbdt", "dart"]}

# %%
rand_search_stacked = RandomizedSearchCV(stacked, rand_params_stacked, n_iter=30, scoring = "f1", cv = cv)
rand_search_stacked.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedShuffleSplit(n_splits=5,
#             random_state=RandomState(MT19937) at 0x1B6B5BEC240,
#             test_size=None, train_size=None),
#                    estimator=StackingClassifier(cv=5,
#                                                 estimators=[('clf_fav_model_balanced',
#                                                              DecisionTreeClassifier(ccp_alpha=1e-05,
#                                                                                     class_weight='balanced',
#                                                                                     criterion='entropy',
#                                                                                     max_depth=25,
#                                                                                     min_impurity_decrease=3e-06,
#                                                                                     min_samples_split...
#                                         'final_estimator__max_depth': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001B680F0C670>,
#                                         'final_estimator__n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001B6808A7910>,
#                                         'final_estimator__num_leaves': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001B6C5AB4310>,
#                                         'final_estimator__subsample': array([0.6, 0.7, 0.8, 0.9])},
#                    scoring='f1')

# %%
rand_search_stacked.best_score_
# Out:
# 0.6185907535689253

# %%
rand_search_stacked.best_params_
# Out:
# {'final_estimator__boosting_type': 'dart',
#  'final_estimator__colsample_bytree': 0.8999999999999999,
#  'final_estimator__learning_rate': 0.25,
#  'final_estimator__max_depth': 8,
#  'final_estimator__n_estimators': 146,
#  'final_estimator__num_leaves': 17,
#  'final_estimator__subsample': 0.6}

# %%
from plotting import plot_learning_curve, plot_validation_curve

# %%
val_boosting_type = plot_validation_curve(stacked, X_train, y_train, cv = cv, 
                                      param_name ="final_estimator__boosting_type", param_range = ["gbdt", "dart", "goss"], scoring = "f1")

# %%
val_learning_rate = plot_validation_curve(stacked, X_train, y_train, cv=cv,
                                              param_name = "final_estimator__learning_rate", param_range = np.arange(0.05,1,0.05), scoring="f1")

# %%
val_is_unbalance = plot_validation_curve(stacked, X_train, y_train, cv=cv,
                                              param_name = "final_estimator__is_unbalance", param_range = [True, False], scoring="f1")

# %%
val_scale_pos_weight = plot_validation_curve(stacked, X_train, y_train, cv=cv,
                                              param_name = "final_estimator__scale_pos_weight", param_range = [1, 1.5, 1.965], scoring="f1")

# %%
val_metric = plot_validation_curve(stacked, X_train, y_train, cv=cv,
                                              param_name = "final_estimator__metric", param_range = ["binary_logloss", "auc"], scoring="f1")

# %%
val_lambda_l1 = plot_validation_curve(stacked, X_train, y_train, cv=cv,
                                              param_name = "final_estimator__reg_alpha", param_range = np.arange(0,20,1), scoring="f1")

# %%
val_lambda_l2 = plot_validation_curve(stacked, X_train, y_train, cv=cv,
                                              param_name = "final_estimator__reg_lambda", param_range = np.arange(0,20,1), scoring="f1")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 val_lambda_l2 = plot_validation_curve(stacked, X_train, y_train, cv=cv,
#       2                                               param_name = "final_estimator__reg_lambda", param_range = np.arange(0,20,1), scoring="f1")
#
# File ~\Desktop\CodingNomads\pyex201\Capstone\04_modelling\plotting.py:174, in plot_validation_curve(estimator, X, y, ylim, cv, n_jobs, param_name, param_range, scoring)
#     119 def plot_validation_curve(
#     120     estimator,
#     121     X,
#    (...)
#     128     scoring=None,
#     129 ):
#     130     """
#     131     referred from :
#     132     https://scikit-learn.org/stable/modules/model_evaluation.html#classification-metrics
#    (...)
#     172
#     173     """
# --> 174     train_scores, test_scores = validation_curve(
#     175         estimator,
#     176         X,
#     177         y,
#     178         param_name=param_name,
#     179         param_range=param_range,
#     180         scoring=scoring,
#     181         n_jobs=n_jobs,
#     182         cv=cv,
#     183     )
#     184     train_scores_mean = np.mean(train_scores, axis=1)
#     185     train_scores_std = np.std(train_scores, axis=1)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:1830, in validation_curve(estimator, X, y, param_name, param_range, groups, cv, scoring, n_jobs, pre_dispatch, verbose, error_score, fit_params)
#    1827 scorer = check_scoring(estimator, scoring=scoring)
#    1829 parallel = Parallel(n_jobs=n_jobs, pre_dispatch=pre_dispatch, verbose=verbose)
# -> 1830 results = parallel(
#    1831     delayed(_fit_and_score)(
#    1832         clone(estimator),
#    1833         X,
#    1834         y,
#    1835         scorer,
#    1836         train,
#    1837         test,
#    1838         verbose,
#    1839         parameters={param_name: v},
#    1840         fit_params=fit_params,
#    1841         return_train_score=True,
#    1842         error_score=error_score,
#    1843     )
#    1844     # NOTE do not change order of iteration to allow one time cv splitters
#    1845     for train, test in cv.split(X, y, groups)
#    1846     for v in param_range
#    1847 )
#    1848 n_params = len(param_range)
#    1850 results = _aggregate_score_dicts(results)
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_stacking.py:488, in StackingClassifier.fit(self, X, y, sample_weight)
#     486 self._le = LabelEncoder().fit(y)
#     487 self.classes_ = self._le.classes_
# --> 488 return super().fit(X, self._le.transform(y), sample_weight)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_stacking.py:193, in _BaseStacking.fit(self, X, y, sample_weight)
#     186 self.stack_method_ = [
#     187     self._method_name(name, est, meth)
#     188     for name, est, meth in zip(names, all_estimators, stack_method)
#     189 ]
#     190 fit_params = (
#     191     {"sample_weight": sample_weight} if sample_weight is not None else None
#     192 )
# --> 193 predictions = Parallel(n_jobs=self.n_jobs)(
#     194     delayed(cross_val_predict)(
#     195         clone(est),
#     196         X,
#     197         y,
#     198         cv=deepcopy(cv),
#     199         method=meth,
#     200         n_jobs=self.n_jobs,
#     201         fit_params=fit_params,
#     202         verbose=self.verbose,
#     203     )
#     204     for est, meth in zip(all_estimators, self.stack_method_)
#     205     if est != "drop"
#     206 )
#     208 # Only not None or not 'drop' estimators will be used in transform.
#     209 # Remove the None from the method as well.
#     210 self.stack_method_ = [
#     211     meth
#     212     for (meth, est) in zip(self.stack_method_, all_estimators)
#     213     if est != "drop"
#     214 ]
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~\anaconda3\lib\threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
val_num_leaves = plot_validation_curve(stacked, X_train, y_train, cv=cv,
                                              param_name = "final_estimator__num_leaves", param_range = np.arange(10,100,5), scoring="f1")

# %%
val_max_depth = plot_validation_curve(stacked, X_train, y_train, cv=cv,
                                              param_name = "final_estimator__max_depth", param_range = np.arange(2,15,1), scoring="f1")

# %%
val_colsample_bytree = plot_validation_curve(stacked, X_train, y_train, cv=cv,
                                              param_name = "final_estimator__colsample_bytree", param_range = np.arange(0.2, 1, 0.1), scoring="f1")

# %%
val_max_bin = plot_validation_curve(stacked, X_train, y_train, cv=cv,
                                              param_name = "final_estimator__max_bin", param_range = np.arange(5, 60, 5), scoring="f1")

# %%
val_min_child_samples = plot_validation_curve(stacked, X_train, y_train, cv=cv,
                                              param_name = "final_estimator__min_child_samples", param_range = np.arange(5, 100, 5), scoring="f1")

# %%
val_min_child_samples = plot_validation_curve(stacked, X_train, y_train, cv=cv,
                                              param_name = "final_estimator__min_child_samples", param_range = np.arange(20, 500, 20), scoring="f1")

# %%
val_min_split_gain = plot_validation_curve(stacked, X_train, y_train, cv=cv,
                                              param_name = "final_estimator__min_split_gain", param_range = np.arange(0, 15, 1), scoring="f1")

# %%
val_n_estimators = plot_validation_curve(stacked, X_train, y_train, cv=cv,
                                              param_name = "final_estimator__n_estimators", param_range = np.arange(50, 500, 25), scoring="f1")
