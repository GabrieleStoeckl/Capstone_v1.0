# %%
import numpy as np
import pandas as pd

# %%
data_causal = pd.read_csv("data/causal_data.csv")

# %%
data_causal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36786524 entries, 0 to 36786523
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   PRODUCT_ID  int64
#  1   STORE_ID    int64
#  2   WEEK_NO     int64
#  3   display     object
#  4   mailer      object
# dtypes: int64(3), object(2)
# memory usage: 1.4+ GB

# %%
conda install -c conda-forge fastparquet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Gabriele\anaconda3
#
#   added / updated specs:
#     - fastparquet
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boltons-23.0.0             |     pyhd8ed1ab_0         296 KB  conda-forge
#     conda-23.3.1               |   py39haa95532_0         972 KB
#     fastparquet-0.5.0          |   py39h080aedc_2         176 KB
#     jsonpatch-1.32             |     pyhd8ed1ab_0          14 KB  conda-forge
#     jsonpointer-2.0            |             py_0           9 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     thrift-0.13.0              |   py39h415ef7b_2         115 KB  conda-forge
#     ------------------------------------------------------------
# ...

# %%
data_causal.to_parquet("data/causal_data.parquet")

# %%
data_causal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36786524 entries, 0 to 36786523
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   PRODUCT_ID  int64
#  1   STORE_ID    int64
#  2   WEEK_NO     int64
#  3   display     object
#  4   mailer      object
# dtypes: int64(3), object(2)
# memory usage: 1.4+ GB

# %%
data_causal.head()
# Out:
#    PRODUCT_ID  STORE_ID  WEEK_NO display mailer
# 0       26190       286       70       0      A
# 1       26190       288       70       0      A
# 2       26190       289       70       0      A
# 3       26190       292       70       0      A
# 4       26190       293       70       0      A
